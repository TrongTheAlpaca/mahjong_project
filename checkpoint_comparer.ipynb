# %%
import torch
from pathlib import Path

# %%
x1 = torch.load(p1)
x2 = torch.load(p2)

# %%
x1['model_state']['mha1.in_proj_weight'].shape
# Out:
# torch.Size([1122, 374])

# %%
x2['model_state']['mha1.out_proj.weight'].shape
# Out:
# torch.Size([374, 374])

# %%
for k in x1['model_state'].keys():
    print(torch.equal(x1['model_state'][k], x2['model_state'][k]))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
for epoch in range(15):
    
    p1 = Path('model_checkpoints') / 'MHA-34-POOL-NEW-2021-05-11'      / f'epoch-0{epoch:02}.pt'
    p2 = Path('model_checkpoints') / 'MHA-34-POOL-BALANCED-2021-05-08' / f'epoch-0{epoch:02}.pt'
    p3 = Path('model_checkpoints') / 'MHA-1-POOL-2021-05-05'           / f'epoch-0{epoch:02}.pt'
    
    x1 = torch.load(p1)
    x2 = torch.load(p2)
    x3 = torch.load(p3)
    
    for k in x1['model_state'].keys():
        print(torch.equal(x1['model_state'][k], x2['model_state'][k]))
        print(torch.equal(x2['model_state'][k], x3['model_state'][k]))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...
